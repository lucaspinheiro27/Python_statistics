# %% [markdown]
# <a href="https://colab.research.google.com/github/lucaspinheiro27/Python_statistics/blob/main/dataframes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import squared

testData = np.arange(-5, 10)
out = squared.incomeandexpenses(testData)

print('You have earned {0:5.2f} EUR, and spent {1:5.2f} EUR.'.format(out[0], -out[1]))
# Out:
# 0 0
# 1 1
# 2 4
# 3 9
# 4 16
# 5 25
# Done
# ['abc', 'def', 'ghij', 'klm']
# You have earned 45.00 EUR, and spent 15.00 EUR.

# %% [markdown]
# # Dataframes

# %%
import pandas as pd

t = np.arange(0, 10, 0.1)
x = np.sin(t)
y = np.cos(t)

df = pd.DataFrame({'Time':t, 'x':x, 'y':y})

# %%
df.Time
# Out:
# 0     0.0
# 1     0.1
# 2     0.2
# 3     0.3
# 4     0.4
#      ...
# 95    9.5
# 96    9.6
# 97    9.7
# 98    9.8
# 99    9.9
# Name: Time, Length: 100, dtype: float64

# %% [markdown]
# * asking for a list

# %%
data = df[['Time', 'y']]

# %%
data.head()
# Out:
#    Time         y
# 0   0.0  1.000000
# 1   0.1  0.995004
# 2   0.2  0.980067
# 3   0.3  0.955336
# 4   0.4  0.921061

# %%
data.tail()
# Out:
#     Time         y
# 95   9.5 -0.997172
# 96   9.6 -0.984688
# 97   9.7 -0.962365
# 98   9.8 -0.930426
# 99   9.9 -0.889191

# %%
data[4:10]
# Out:
#    Time         y
# 4   0.4  0.921061
# 5   0.5  0.877583
# 6   0.6  0.825336
# 7   0.7  0.764842
# 8   0.8  0.696707
# 9   0.9  0.621610

# %%
df[['Time', 'y']][4:10]
# Out:
#    Time         y
# 4   0.4  0.921061
# 5   0.5  0.877583
# 6   0.6  0.825336
# 7   0.7  0.764842
# 8   0.8  0.696707
# 9   0.9  0.621610

# %% [markdown]
# * row and column

# %%
df.iloc[4:10, [0,2]]
# Out:
#    Time         y
# 4   0.4  0.921061
# 5   0.5  0.877583
# 6   0.6  0.825336
# 7   0.7  0.764842
# 8   0.8  0.696707
# 9   0.9  0.621610

# %%
# data.values

# %% [markdown]
# * Grouping

# %%
import matplotlib.pyplot as plt

data = pd.DataFrame({
'Gender': ['f', 'f', 'm', 'f', 'm',
'm', 'f', 'm', 'f', 'm', 'm'],
'TV': [3.4, 3.5, 2.6, 4.7, 4.1, 4.1,
5.1, 3.9, 3.7, 2.1, 4.3]
})

grouped = data.groupby('Gender')

print(grouped.describe())
# Out:
#           TV
#        count      mean       std  min    25%  50%  75%  max
# Gender
# f        5.0  4.080000  0.769415  3.4  3.500  3.7  4.7  5.1
# m        6.0  3.516667  0.926103  2.1  2.925  4.0  4.1  4.3

# %%
grouped.boxplot()
plt.show()

# %%
df_female = grouped.get_group('f')
values_female = grouped.get_group('f').values

# %% [markdown]
# # Statsmodel

# %%
import statsmodels.formula.api as sm

x = np.arange(100)
y = 0.5*x - 20 + np.random.randn(len(x))
df = pd.DataFrame({'x':x, 'y':y})

model = sm.ols('y~x', data=df).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.996
# Method:                 Least Squares   F-statistic:                 2.234e+04
# Date:                Tue, 08 Oct 2024   Prob (F-statistic):          1.89e-117
# Time:                        23:44:12   Log-Likelihood:                -137.67
# No. Observations:                 100   AIC:                             279.3
# Df Residuals:                      98   BIC:                             284.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -20.0983      0.192   -104.557      0.000     -20.480     -19.717
# x              0.5014      0.003    149.471      0.000       0.495       0.508
# ==============================================================================
# Omnibus:                        2.219   Durbin-Watson:                   1.793
# Prob(Omnibus):                  0.330   Jarque-Bera (JB):                2.134
# Skew:                           0.283   Prob(JB):                        0.344
# Kurtosis:                       2.562   Cond. No.                         114.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # success ~ intelligence * diligence

# %%
import seaborn as sns
x = np.linspace(1, 7, 50)
y = 3 + 2 * x + 1.5 * np.random.randn(len(x))
df = pd.DataFrame({'xData': x, 'yData': y})

sns.regplot(x='xData', y='yData', data=df)
plt.show()

# %% [markdown]
# • Generate a pandas DataFrame, with the x-column time stamps from 0 to 10 s, at a
# rate of 10 Hz, the y-column data values with a sine with 1.5 Hz, and the z-column
# the corresponding cosine values. Label the x-column “Time”, and the y-column
# “YVals”, and the z-column “ZVals”.
#
# • Show the head of this DataFrame.
#
# • Extract the data in lines 10–15 from “Yvals” and “ZVals”, and write them to the
# file “out.txt”.

# %%
df = pd.read_csv('/content/swim100m.csv')
df.head()
# Out:
#    year  time sex
# 0  1905  65.8   M
# 1  1908  65.6   M
# 2  1910  62.8   M
# 3  1912  61.6   M
# 4  1918  61.4   M

# %%
df = pd.read_csv('/content/WeightLoss.csv')
df.tail()
# Out:
#        When   Start      End  Days  Weeks  WeightLoss
# 438  25-May  5/4/08  5/18/08  14.0    2.0        15.4
# 439  25-May     NaN      NaN   NaN    NaN         NaN
# 440  25-May     NaN      NaN   NaN    NaN         NaN
# 441  25-May     NaN      NaN   NaN    NaN         NaN
# 442  25-May     NaN      NaN   NaN    NaN         NaN

# %%
t = np.arange(0, 10, 0.1)
y = np.sin(2 * np.pi * 1.5 * t)
z = np.cos(2 * np.pi * 1.5 * t)

df = pd.DataFrame({'Time': t, 'YVals': y, 'ZVals': z})
df.head()
# Out:
#    Time     YVals     ZVals
# 0   0.0  0.000000  1.000000
# 1   0.1  0.809017  0.587785
# 2   0.2  0.951057 -0.309017
# 3   0.3  0.309017 -0.951057
# 4   0.4 -0.587785 -0.809017

# %%
df[['YVals', 'ZVals']][10:16]
# Out:
#            YVals         ZVals
# 10  3.673940e-16 -1.000000e+00
# 11 -8.090170e-01 -5.877853e-01
# 12 -9.510565e-01  3.090170e-01
# 13 -3.090170e-01  9.510565e-01
# 14  5.877853e-01  8.090170e-01
# 15  1.000000e+00  5.510911e-16

# %%
outfile = 'out.txt'
df[10:16][['YVals', 'ZVals']].to_csv(outfile)
print('Data written to {0}'.format(outfile))
# Out:
# Data written to out.txt
